# %%
import requests
from bs4 import BeautifulSoup
import os
import sys
import time
import json
import re
import random

# %%
class EPcompCrawler():
    BASE_URL = 'http://www.piano-e-competition.com'
    ROOT = 'archive'
    YEARS = ['/midi_2002.asp', '/midi_2004.asp', '/midi_2006.asp',
         '/midi_2008.asp', '/midi_2009.asp', '/midi_2011.asp']
    
    def __init__(self, sleep_time=0.1, log=True):
        self.sleep_time = sleep_time
        self.log = log
        self.mid_cnt = 0
        self.zip_cnt = 0
        
    def _request_url(self, url, doctype='html'):
        response = requests.get(url)

        # sleep
        time.sleep(self.sleep_time)

        # return
        if doctype =='html':
            soup = BeautifulSoup(response.text, 'html.parser')
            return soup
        elif  doctype =='content':
            return response.content
        else:
            return response
        
    def _log_print(self, log, quite=False):
        if not quite:
            print(log)

        if self.log:
            with open("log.txt", "a") as f:
                print(log, file=f)
    
    def fetch_year_songs(self, year_url):
        soup = self._request_url(year_url)
        a_list = soup.find_all('a')
        midi_list = []
        zip_list = []
        print(len(a_list))

        for idx in range(len(a_list)):
            a = a_list[idx]
            self.a = a
            url = a.get('href')
            if  url and (('.MID' in url) or ('.mid' in url)):
                now_performer = re.search('(\D+?)(\d+?).', url.split('/')[-1]).group(1)
                song_name = re.sub( '\s+', ' ', a.text.replace('\r', '').replace('\n', '')).strip()
                try:
                    composer = a.parent.parent.td.text.strip()
                except:
                    try:
                        composer = a.parent.parent.parent.td.text.strip()
                    except:
                        composer = a.parent.parent.parent.parent.td.text.strip()
                    
                print('%-10s |%-40s   |[%s | %s]' % (now_performer, url, song_name, composer))
                midi_list.append((now_performer, url, song_name))

            if  url and (('.ZIP' in url) or ('.zip' in url)):
                zip_fn = url.lstrip('../')
                print('%-10s %s'%(now_performer, zip_fn))
                zip_list.append((now_performer, zip_fn))
        return midi_list, zip_list
    
    def crawl_year_songs(self, midi_list, zip_list, dir_path):
        path_midi = os.path.join(dir_path, 'midi') 
        path_zip = os.path.join(dir_path, 'zip')
            
        if not os.path.exists(path_midi):
            os.makedirs(path_midi)
        if not os.path.exists(path_zip):
            os.makedirs(path_zip)
        
        print('=================midi=================')
        for idx in range(len(midi_list)):
            m_url = midi_list[idx][1]
            
            if '/ecompetition' not in m_url:
                m_url = 'http://www.piano-e-competition.com/ecompetition/' + m_url
            else:
                m_url = self.BASE_URL + m_url

            
            print(idx, m_url)
            content = self._request_url(m_url, doctype='content')
            fn = m_url.split('/')[-1]
                 
            with open(os.path.join(path_midi, fn), "wb") as f:
                f.write(content)
               
        print('=================zip=================')    
        for idx in range(len(zip_list)):
            z_url = zip_list[idx][1]
            z_url = self.BASE_URL + '/' + z_url
            print(idx, z_url)
            content = self._request_url(z_url, doctype='content')
            fn = z_url.split('/')[-1]         
            
            with open(os.path.join(path_zip, fn), "wb") as f:
                f.write(content)
    
    def crawl_archive(self):
        
        if not os.path.exists(self.ROOT):
            os.makedirs(self.ROOT)
        
        archive_dict = dict()
        
        for y in self.YEARS:
            ml, zl = self.fetch_year_songs(self.BASE_URL+y)
            year = re.search('(\d{4}).',y).group(1)
            print('{%s}' % year)
        
            self.mid_cnt += len(ml)
            self.zip_cnt += len(zl)
        
            tmp = {'mid':ml, 'zip':zl}
            archive_dict[year] = tmp 
        
            self.crawl_year_songs(ml, zl, self.ROOT)
        
        with open(os.path.join(self.ROOT, 'archive.json'), "w") as f:
            json.dump(archive_dict)
    
    def run(self):
        s = time.time()
        self.crawl_archive()
        e = time.time()
        
        self._log_print('Total midi files %d'%self.mid_cnt)
        self._log_print('Total zip files %d'%self.zip_cnt)
        self._log_print(time.strftime("\nElapsed time: %H:%M:%S", time.gmtime(s-e)))

# %%
ec = EPcompCrawler()
ec.fetch_year_songs('http://www.piano-e-competition.com/ecompetition/midi_2011.asp')
# Out:
# 392
# Ahfat      |/MIDIFiles/2011/Ahfat01.MID                |[Prelude and Fugue in D Minor, WTC II, BWV 875 | J. S. Bach]
# Ahfat      |/MIDIFiles/2011/Ahfat03.MID                |[Transcendental Etude No. 7, "Eroica" | Franz Liszt]
# Ahfat      |/MIDIFiles/2011/Ahfat04.MID                |[Sonata No. 3 in A Minor, Op. 28 | Sergei Prokofiev]
# Ahfat      MIDIFiles/2011/XPMIDI2011/Ahfat_K_XP.zip
# Ahfat      MIDIFiles/2011/EnhancedMIDI2011/Ahfat_K_SMF.zip
# Ahfat      MIDIFiles/2011/E-SEQ2011/Ahfat_K_ESEQ.zip
# Chon       |/MIDIFiles/2011/Chon01.MID                 |[Etude Op. 25 No. 10 in B Minor | Frederic Chopin]
# Chon       |/MIDIFiles/2011/Chon02.MID                 |[Prelude and Fugue in G Minor, WTC II, BWV 885 | J. S. Bach]
# Chon       |/MIDIFiles/2011/Chon03.MID                 |[Sonata No. 4 in E-flat Major, Op. 7, 1st mov. | Ludwig van Beethoven]
# Chon       |/MIDIFiles/2011/Chon04.MID                 |[Sonata No. 3 in A Minor, Op. 28 | Sergei Prokofiev]
# Chon       |/MIDIFiles/2011/Chon05.MID                 |[Impromptu Op. 142 No. 3, in B-flat Major, D935 | Franz Schubert]
# Chon       |/MIDIFiles/2011/Chon06.MID                 |[Choral et Variations | Henri Dutilleux]
# Chon       |/MIDIFiles/2011/Chon07.MID                 |[Nocturne Op. 27 No. 1 in C-sharp Minor | Frederic Chopin]
# Chon       |/MIDIFiles/2011/Chon08.MID                 |[Polonaise Op. 53 in A-flat Major | Frederic Chopin]
# Chon       |/MIDIFiles/2011/Chon09.MID                 |[Thirty-Two Variations in C Minor, WoO 80 | Ludwig van Beethoven]
# Chon       |/MIDIFiles/2011/Chon10.MID                 |[Two Polyphonic Pieces | Rodion Schedrin]
# Chon       |/MIDIFiles/2011/Chon11.MID                 |[Venezia e Napoli | Franz Liszt]
# Chon       MIDIFiles/2011/XPMIDI2011/Chon_S_XP.zip
# Chon       MIDIFiles/2011/EnhancedMIDI2011/Chon_S_SMF.zip
# Chon       MIDIFiles/2011/E-SEQ2011/Chon_S_ESEQ.zip
# Colafelice |/MIDIFiles/2011/Colafelice01.MID           |[Prelude and Fugue in D Minor, WTC I, BWV 851 | J. S. Bach]
# Colafelice |/MIDIFiles/2011/Colafelice02.MID           |[Sonata No. 5 in C Minor, Op. 10 No. 1, 1st mov. | Ludwig van Beethoven]
# Colafelice |/MIDIFiles/2011/Colafelice03.MID           |[Scherzo No. 4 in E Major, Op. 54 | Frederic Chopin]
# Colafelice |/MIDIFiles/2011/Colafelice04.MID           |[Etude-Tableau, Op. 39 No. 6 in A Minor | Sergei Rachmaninov]
# Colafelice |/MIDIFiles/2011/Colafelice05.MID           |[Toccata from "Le Tombeau de Couperin" | Maurice Ravel]
# Colafelice |/MIDIFiles/2011/Colafelice06.MID           |[Visions Fugitives Op. 22 | Sergei Prokofiev]
# Colafelice |/MIDIFiles/2011/Colafelice07.MID           |[Moment Musical Op. 94 No. 4, in C-sharp Minor, D780 | Franz Schubert]
# Colafelice |/MIDIFiles/2011/Colafelice08.MID           |[Hungarian Rhapsody No. 10, S. 244/10 | Franz Liszt]
# Colafelice |/MIDIFiles/2011/Colafelice09.MID           |[Romances Op. 28, Nos. 2 and 3 | Robert Schumann]
# Colafelice |/MIDIFiles/2011/Colafelice10.MID           |[Variations Serieuses Op. 54 | Felix Mendelssohn]
# Colafelice |/MIDIFiles/2011/Colafelice11.MID           |[Toccata in D Minor, Op. 11 | Sergei Prokofiev]
# Colafelice |/MIDIFiles/2011/Colafelice12.MID           |[Trois Mouvements de Petrouchka | Igor Stravinsky]
# Colafelice MIDIFiles/2011/XPMIDI2011/Colafelice_L_XP.zip
# Colafelice MIDIFiles/2011/EnhancedMIDI2011/Colafelice_L_SMF.zip
# Colafelice MIDIFiles/2011/E-SEQ2011/Colafelice_L_ESEQ.zip
# Giesbrecht |/MIDIFiles/2011/Giesbrecht01.MID           |[Prelude and Fugue in A Minor, WTC II, BWV889 | J. S. Bach]
# Giesbrecht |/MIDIFiles/2011/Giesbrecht02.MID           |[Sonata No. 17 in D Minor, Op. 31 No. 2, 1st mov. | Ludwig van Beethoven]
# Giesbrecht |/MIDIFiles/2011/Giesbrecht03.MID           |[Etude in D-flat Major, Op. 8 No. 10 | Alexander Scriabin]
# Giesbrecht |/MIDIFiles/2011/Giesbrecht04.MID           |[L'isle joyeuse | Claude Debussy]
# Giesbrecht MIDIFiles/2011/XPMIDI2011/Giesbrect_R_XP.zip
# Giesbrecht MIDIFiles/2011/EnhancedMIDI2011/Giesbrecht_R_SMF.zip
# Giesbrecht MIDIFiles/2011/E-SEQ2011/Giesbrecht_R_ESEQ.zip
# Guo        |/MIDIFiles/2011/Guo01.MID                  |[Prelude and Fugue in G Minor, WTC II, BWV 885 | J. S. Bach]
# Guo        |/MIDIFiles/2011/Guo02.MID                  |[Etude Op. 25 No. 10 in B Minor | Frederic Chopin]
# Guo        |/MIDIFiles/2011/Guo03.MID                  |[Sonata No. 23 in F Minor, Op. 57, 1st mov. | Ludwig van Beethoven]
# Guo        |/MIDIFiles/2011/Guo04.MID                  |[Toccata in D Minor, Op. 11 | Sergei Prokofiev]
# Guo        MIDIFiles/2011/XPMIDI2011/Guo_Z_XP.zip
# Guo        MIDIFiles/2011/EnhancedMIDI2011/Guo_Z_SMF.zip
# Guo        MIDIFiles/2011/E-SEQ2011/Guo_Z_ESEQ.zip
# Hou        |/MIDIFiles/2011/Hou01.MID                  |[Prelude and Fugue in B Major, WTC II, BWV 892 | J. S. Bach]
# Hou        |/MIDIFiles/2011/Hou02.MID                  |[Sonata No. 10 in G Major, Op. 14 No. 2, 1st mov. | Ludwig van Beethoven]
# Hou        |/MIDIFiles/2011/Hou03.MID                  |[Etude Op. 25 No. 12 in C Mnor | Frederic Chopin]
# Hou        |/MIDIFiles/2011/Hou04.MID                  |[Fantasy in B Minor, Op. 28 | Alexander Scriabin]
# Hou        |/MIDIFiles/2011/Hou05.MID                  |[Rigoletto Paraphrase, S. 434 | Franz Liszt]
# Hou        |/MIDIFiles/2011/Hou06.MID                  |[Impromptu Op. 90 No. 3, In G-flat Major, D899 | Franz Schubert]
# Hou        |/MIDIFiles/2011/Hou07.MID                  |[Sonata, Op. 26 | Samuel Barber]
# Hou        MIDIFiles/2011/XPMIDI2011/Hou_K_XP.zip
# Hou        MIDIFiles/2011/EnhancedMIDI2011/Hou_K_SMF.zip
# Hou        MIDIFiles/2011/E-SEQ2011/Hou_K_ESEQ.zip
# Kim        |/MIDIFiles/2011/Kim01.MID                  |[Prelude from the English Suite No. 2 in A Minor, BWV 807 | J. S. Bach]
# Kim        |/MIDIFiles/2011/Kim02.MID                  |[Sonata No. 26 in E-flat Major, Op. 81a, 1st mov. | Ludwig van Beethoven]
# Kim        |/MIDIFiles/2011/Kim03.MID                  |[Etude Op. 25 No. 11 in A Minor | Frederic Chopin]
# Kim        |/MIDIFiles/2011/Kim04.MID                  |[Ballade No. 1 in G Minor, Op. 23 | Frederic Chopin]
# Kim        |/MIDIFiles/2011/Kim05.MID                  |[Annes de Pelerinage III: Le jeux d'eau a la Villa d"Este | Franz Liszt]
# Kim        |/MIDIFiles/2011/Kim06.MID                  |[Impromptu Op. 142 No. 3 in B-flat Major, D935 | Franz Schubert]
# Kim        |/MIDIFiles/2011/Kim07.MID                  |[Sonata No. 3 in A Minor, Op. 28 | Sergei Prokofiev]
# Kim        |/MIDIFiles/2011/Kim08.MID                  |[Liebesfreud | F. Kreisler/S. Rachmaninoff]
# Kim        |/MIDIFiles/2011/Kim09.MID                  |[Thirty-Two Variations in C Minor, WoO 80 | Ludwig van Beethoven]
# Kim        |/MIDIFiles/2011/Kim10.MID                  |[Moments Musicaux, Op. 16 | Sergei Rachmaninov]
# Kim        MIDIFiles/2011/XPMIDI2011/Kim_S_XP.zip
# Kim        MIDIFiles/2011/EnhancedMIDI2011/Kim_S_SMF.zip
# Kim        MIDIFiles/2011/E-SEQ2011/Kim_S_ESEQ.zip
# Kurz       |/MIDIFiles/2011/Kurz01.MID                 |[Prelude and Fugue in D Major, WTC II, BWV 874 | J. S. Bach]
# Kurz       |/MIDIFiles/2011/Kurz02.MID                 |[Sonata in E-flat Major, Hob. XVI:52, 1st mov. | Franz Joseph Haydn]
# Kurz       |/MIDIFiles/2011/Kurz03.MID                 |[Etude Op. 10 No. 4 in C-sharp Minor | Frederic Chopin]
# Kurz       |/MIDIFiles/2011/Kurz04.MID                 |[Scherzo No. 1 in B Minor, Op. 20 | Frederic Chopin]
# Kurz       MIDIFiles/2011/XPMIDI2011/Kurz_A_XP.zip
# Kurz       MIDIFiles/2011/EnhancedMIDI2011/Kurz_A_SMF.zip
# Kurz       MIDIFiles/2011/E-SEQ2011/Kurz_A_ESEQ.zip
# Lan        |/MIDIFiles/2011/Lan01.MID                  |[Prelude and Fugue in F Minor, WTC I, BWV 857 | J. S. Bach]
# Lan        |/MIDIFiles/2011/Lan02.MID                  |[Concert Etude No. 2, "La Leggierezza", S. 144/2 | Franz Liszt]
# Lan        |/MIDIFiles/2011/Lan03.MID                  |[Sonata in G Major, Hob. XVI:6, 1st mov. | Franz Joseph Haydn]
# Lan        |/MIDIFiles/2011/Lan04.MID                  |[Rondo in A Minor, K. 511 | Wolfgang Amadeus Mozart]
# Lan        MIDIFiles/2011/XPMIDI2011/Lan_B_XP.zip
# Lan        MIDIFiles/2011/EnhancedMIDI2011/Lan_B_SMF.zip
# Lan        MIDIFiles/2011/E-SEQ2011/Lan_B_ESEQ.zip
# Lee        |/MIDIFiles/2011/Lee01.MID                  |[Prelude and Fugue in D-flat Major, WTCI, BWV 848 | J. S. Bach]
# Lee        |/MIDIFiles/2011/Lee02.MID                  |[Sonata No. 17 in D Minor, Op. 31 No. 2, 1st mov. | Ludwig van Beethoven]
# Lee        |/MIDIFiles/2011/Lee03.MID                  |[ABEGG Variations, Op. 1 | Robert Schumann]
# Lee        |/MIDIFiles/2011/Lee04.MID                  |[Concert Etude No. 3 in D-flat Major, "Un Sospiro", S. 144/3 | Franz Liszt]
# Lee        MIDIFiles/2011/XPMIDI2011/Lee_C_XP.zip
# Lee        MIDIFiles/2011/EnhancedMIDI2011/Lee_C_SMF.zip
# Lee        MIDIFiles/2011/E-SEQ2011/Lee_C_ESEQ.zip
# Lin        |/MIDIFiles/2011/Lin01.MID                  |[Prelude from the English Suite No. 6 in D Minor, BWV 811 | J. S. Bach]
# Lin        |/MIDIFiles/2011/Lin02.MID                  |[Sonata Op. 25 No. 5 in F-sharp Minor, 1st mov. | Muzio Clementi]
# Lin        |/MIDIFiles/2011/Lin03.MID                  |[Etude Op. 7 No. 4 | Igor Stravinsky]
# Lin        |/MIDIFiles/2011/Lin04.MID                  |[Hungarian Rhapsody No. 13, S. 244/13 | Franz Liszt]
# Lin        |/MIDIFiles/2011/Lin05.MID                  |[Impromptu Op. 142 No. 3 in B-flat Major, D935 | Franz Schubert]
# Lin        |/MIDIFiles/2011/Lin06.MID                  |[Ballade No. 3 in A-flat Major, Op. 47 | Frederic Chopin]
# Lin        |/MIDIFiles/2011/Lin07.MID                  |[Choral et Variations | Henri Dutilleux]
# Lin        MIDIFiles/2011/XPMIDI2011/Lin_P_XP.zip
# Lin        MIDIFiles/2011/EnhancedMIDI2011/Lin_P_SMF.zip
# Lin        MIDIFiles/2011/E-SEQ2011/Lin_P_ESEQ.zip
# Lou        |/MIDIFiles/2011/Lou01.MID                  |[Prelude and Fugue in C-sharp Major, WTC I, BWV 848 | J. S. Bach]
# Lou        |/MIDIFiles/2011/Lou02.MID                  |[Sonata No. 24 in F-sharp Major, Op. 78 | Ludwig van Beethoven]
# Lou        |/MIDIFiles/2011/Lou03.MID                  |[Etudes Op. 10 Nos. 8 and 9 | Frederic Chopin]
# Lou        |/MIDIFiles/2011/Lou04.MID                  |[In Memoriam to the VIctims of Chernobyl | Larysa Kuzmenko]
# Lou        MIDIFiles/2011/XPMIDI2011/Lou_V_XP.zip
# Lou        MIDIFiles/2011/EnhancedMIDI2011/Lou_V_SMF.zip
# Lou        MIDIFiles/2011/E-SEQ2011/Lou_V_ESEQ.zip
# Lu         |/MIDIFiles/2011/Lu01.MID                   |[Prelude from the English Suite No. 1 in A Minor, BWV 806 | J. S. Bach]
# Lu         |/MIDIFiles/2011/Lu02.MID                   |[Sonata in B-flat Major, K 281, 1st mov. | Wolfgang Amadeus Mozart]
# Lu         |/MIDIFiles/2011/Lu03.MID                   |[Concert Etude No. 2, "Gnomenreigen", S. 145/2 | Franz Liszt]
# Lu         |/MIDIFiles/2011/Lu04.MID                   |[Excursions Op. 20 Nos. 1, 3 and 4 | Samuel Barber]
# Lu         |/MIDIFiles/2011/Lu05.MID                   |[Impromptu Op. 142 No. 4, in F Minor, D935 | Franz Schubert]
# Lu         |/MIDIFiles/2011/Lu06.MID                   |[Nocturne Op. 32 No. 2 in A-flat Major | Frederic Chopin]
# Lu         |/MIDIFiles/2011/Lu07.MID                   |[Sarcasms, Op. 17 | Sergei Prokofiev]
# Lu         MIDIFiles/2011/XPMIDI2011/Lu_X_XP.zip
# Lu         MIDIFiles/2011/EnhancedMIDI2011/Lu_X_SMF.zip
# Lu         MIDIFiles/2011/E-SEQ2011/Lu_X_ESEQ.zip
# Mizumoto   |/MIDIFiles/2011/Mizumoto01.MID             |[Sonata in E-flat Major, Hob. XVI: 52, 1st mov. | Franz Joseph Haydn]
# Mizumoto   |/MIDIFiles/2011/Mizumoto02.MID             |[Ballade No. 4 in F Minor, Op. 52 | Frederic Chopin]
# Mizumoto   |/MIDIFiles/2011/Mizumoto03.MID             |[Prelude and Fugue in C-sharp Major, WTC I, BWV 848 | J. S. Bach]
# Mizumoto   |/MIDIFiles/2011/Mizumoto04.MID             |[Etude No. 13, "Lescalier du Diable" | Gyorgy Ligeti]
# Mizumoto   |/MIDIFiles/2011/Mizumoto05.MID             |[Elegie in E-flat Minor, Op. 3 | Sergei Rachmaninoff]
# Mizumoto   |/MIDIFiles/2011/Mizumoto06.MID             |[Sonata No. 23 in F Minor, Op. 57, 1st mov. | Ludwig van Beethoven]
# Mizumoto   |/MIDIFiles/2011/Mizumoto07.MID             |[Impromptu Op. 90, No. 3 in G-flat Major, D899 | Franz Schubert]
# Mizumoto   |/MIDIFiles/2011/Mizumoto08.MID             |[Staendchen, S. 558, No. 9, "Horch, horch! Die Lerch" | F. Schubert/F. Liszt]
# Mizumoto   |/MIDIFiles/2011/Mizumoto09.MID             |[Sonata Op. 26, 4th mov. | Samuel Barber]
# Mizumoto   |/MIDIFiles/2011/Mizumoto10.MID             |[Mazurka Op. 6 No. 2 in C-sharp Minor | Frederic Chopin]
# Mizumoto   |/MIDIFiles/2011/Mizumoto11.MID             |[Thirty-Two Variations in C Minor, WoO 80 | Ludwig van Beethoven]
# Mizumoto   |/MIDIFiles/2011/Mizumoto12.MID             |[Sonata No. 2 in B-flat Minor, Op. 36 (1913) | Sergei Rachmaninov]
# Mizumoto   MIDIFiles/2011/XPMIDI2011/Mizumoto_W_XP.zip
# Mizumoto   MIDIFiles/2011/EnhancedMIDI2011/Mizumoto_W_SMF.zip
# Mizumoto   MIDIFiles/2011/E-SEQ2011/Mizumoto_W_ESEQ.zip
# Ozaki      |/MIDIFiles/2011/Ozaki01.MID                |[Prelude and Fugue in E Major, WTC I, BWV 854 | J. S. Bach]
# Ozaki      |/MIDIFiles/2011/Ozaki02.MID                |[Sonata in D Major, K. 284, 1st mov. | Wolfgang Amadeus Mozart]
# Ozaki      |/MIDIFiles/2011/Ozaki03.MID                |[Etude in G-sharp Minor, Op. 25 No. 6 | Frederic Chopin]
# Ozaki      |/MIDIFiles/2011/Ozaki04.MID                |[Concert Etude No. 2, "La Leggierezza", S. 144/2 | Franz Liszt]
# Ozaki      |/MIDIFiles/2011/Ozaki05.MID                |[Hungarian Rhapsody No. 12, S. 244/12 | Franz Liszt]
# Ozaki      |/MIDIFiles/2011/Ozaki06.MID                |[Prelude in G-sharp Minor, Op. 32 No. 12 | Sergei Rachmaninov]
# Ozaki      |/MIDIFiles/2011/Ozaki07.MID                |[Impromptu Op. 142 No. 1, in F Minor, D935 | Franz Schubert]
# Ozaki      |/MIDIFiles/2011/Ozaki08.MID                |[Die Forelle | F. Schubert/F. Liszt]
# Ozaki      |/MIDIFiles/2011/Ozaki09.MID                |[Variations in B-flat Minor, Op. 3 | Karon Szymanowski]
# Ozaki      |/MIDIFiles/2011/Ozaki10.MID                |[Sonata in B-flat Major, Hob. XVI:41 | Franz Joseph Haydn]
# Ozaki      |/MIDIFiles/2011/Ozaki11.MID                |[Variations Serieuses, Op. 54 | Felix Mendelssohn]
# Ozaki      |/MIDIFiles/2011/Ozaki12.MID                |[Scherzo from A Midsummer Night's Dream | F. Mendelssohn/S. Rachmaninov]
# Ozaki      |/MIDIFiles/2011/Ozaki13.MID                |[In the Garden , Etude-Idyll | Mily Balakirev]
# Ozaki      |/MIDIFiles/2011/Ozaki14.MID                |[Danse Macabre S.555/R.240 | F. Liszt/C. Saint-Saens]
# Ozaki      MIDIFiles/2011/XPMIDI2011/Ozaki_M_XP.zip
# Ozaki      MIDIFiles/2011/EnhancedMIDI2011/Ozaki_M_SMF.zip
# Ozaki      MIDIFiles/2011/E-SEQ2011/Ozaki_M_ESEQ.zip
# Rizikov    |/MIDIFiles/2011/Rizikov01.MID              |[Prelude and Fugue in A Minor, WTC I, BWV 865 | J. S. Bach]
# Rizikov    |/MIDIFiles/2011/Rizikov02.MID              |[Sonata No. 17 in D Minor, Op. 31 No. 2, 1st mov. | Ludwig van Beethoven]
# Rizikov    |/MIDIFiles/2011/Rizikov03.MID              |[Etude Op. 10 No. 8 in F Major | Frederic Chopin]
# Rizikov    |/MIDIFiles/2011/Rizikov04.MID              |[Rondo in C Minor, Op. 1 | Frederic Chopin]
# Rizikov    MIDIFiles/2011/XPMIDI2011/Rizikov_A_XP.zip
# Rizikov    MIDIFiles/2011/EnhancedMIDI2011/Rizikov_A_SMF.zip
# Rizikov    MIDIFiles/2011/E-SEQ2011/Rizikov_A_ESEQ.zip
# Sham       |/MIDIFiles/2011/Sham01.MID                 |[Prelude and Fugue in B-flat Minor, WTC I, BWV 867 | Johann Sebastian Bach]
# Sham       |/MIDIFiles/2011/Sham02.MID                 |[Etude Op. 25 No. 11 in A Minor | Frederic Chopin]
# Sham       |/MIDIFiles/2011/Sham03.MID                 |[Sonata No. 26 in E-flat Major, Op. 81a, 1st mov. | Ludwig van Beethoven]
# Sham       |/MIDIFiles/2011/Sham04.MID                 |[Rondo Capriccioso in E Minor, Op. 14 | Felix Mendelssohn]
# Sham       |/MIDIFiles/2011/Sham05.MID                 |[Ballade No. 2 in B Minor, S. 171 | Franz Liszt]
# Sham       |/MIDIFiles/2011/Sham06.MID                 |[Impromptu Op. 90 No. 3, in G-flat Major, D899 | Franz Schubert]
# Sham       |/MIDIFiles/2011/Sham07.MID                 |[Trois Pieces pour Piano | Francis Poulenc]
# Sham       |/MIDIFiles/2011/Sham08.MID                 |[Variations Serieuses, Op. 54 | Felix Mendelssohn]
# Sham       |/MIDIFiles/2011/Sham09.MID                 |[Sonata No. 6 in A Major, Op. 82 | Sergei Prokofiev]
# Sham       MIDIFiles/2011/XPMIDI2011/Sham_A_XP.zip
# Sham       MIDIFiles/2011/EnhancedMIDI2011/Sham_A_SMF.zip
# Sham       MIDIFiles/2011/E-SEQ2011/Sham_A_ESEQ.zip
# Shychko    |/MIDIFiles/2011/Shychko01.MID              |[Prelude and Fugue in G-sharp Minor, WTC I, BWV 863 | J. S. Bach]
# Shychko    |/MIDIFiles/2011/Shychko02.MID              |[Sonata No. 21 in C Major, Op. 53, 1st mov. | Ludwig van Beethoven]
# Shychko    |/MIDIFiles/2011/Shychko03.MID              |[Etude Op. 25 No. 11 in A Minor | Frederic Chopin]
# Shychko    |/MIDIFiles/2011/Shychko04.MID              |[Two Preludes from Op. 28, Nos. 15 and 24 | Frederic Chopin]
# Shychko    MIDIFiles/2011/XPMIDI2011/Shychko_A_XP.zip
# Shychko    MIDIFiles/2011/EnhancedMIDI2011/Shychko_A_SMF.zip
# Shychko    MIDIFiles/2011/E-SEQ2011/Shychko_A_ESEQ.zip
# Sladek     |/MIDIFiles/2011/Sladek01.MID               |[Prelude and Fugue in D Major, WTC I, BWV 850 | J. S. Bach]
# Sladek     |/MIDIFiles/2011/Sladek02.MID               |[Sonata No. 21 in C Major, Op. 53, 1st mov. | Ludwig van Beethoven]
# Sladek     |/MIDIFiles/2011/Sladek03.MID               |[Etude Op. 10 No. 4 in C-sharp Minor | Frederic Chopin]
# Sladek     |/MIDIFiles/2011/Sladek04.MID               |[Ballade No. 1 in G Minor, Op. 23 | Frederic Chopin]
# Sladek     MIDIFiles/2011/XPMIDI2011/Sladek_J_XP.zip
# Sladek     MIDIFiles/2011/EnhancedMIDI2011/Sladek_J_SMF.zip
# Sladek     MIDIFiles/2011/E-SEQ2011/Sladek_J_ESEQ.zip
# Song       |/MIDIFiles/2011/Song01.MID                 |[Prelude and Fugue in E-flat Major, WTC II, BWV 876 | J. S. Bach]
# Song       |/MIDIFiles/2011/Song02.MID                 |[Etude Op. 25 No. 11 in A Minor | Frederic Chopin]
# Song       |/MIDIFiles/2011/Song03.MID                 |[Sonata No. 21 in C Major, Op. 53, 1st mov. | Ludwig van Beethoven]
# Song       |/MIDIFiles/2011/Song04.MID                 |[Toccata in D Minor, Op. 11 | Sergei Prokofiev]
# Song       MIDIFiles/2011/XPMIDI2011/Song_Z_XP.zip
# Song       MIDIFiles/2011/EnhancedMIDI2011/Song_Z_SMF.zip
# Song       MIDIFiles/2011/E-SEQ2011/Song_Z_ESEQ.zip
# Teo        |/MIDIFiles/2011/Teo01.MID                  |[Prelude and Fugue in A Minor, WTC I, BWV 865 | J. S. Bach]
# Teo        |/MIDIFiles/2011/Teo02.MID                  |[Sonata No. 23 in F Minor, Op. 57, 1st mov. | Ludwig van Beethoven]
# Teo        |/MIDIFiles/2011/Teo03.MID                  |[Alborada del grcioso from Miroirs | Maurice Ravel]
# Teo        |/MIDIFiles/2011/Teo04.MID                  |["Toccatina" Concert Etude Op. 40 No. 3 | Nikolai Kapustin]
# Teo        |/MIDIFiles/2011/Teo05.MID                  |[Impromptu Op. 90 No. 1, in C Minor, D899 | Franz Schubert]
# Teo        |/MIDIFiles/2011/Teo06.MID                  |[Toccata in D Minor, Op. 11 | Sergei Prokofiev]
# Teo        |/MIDIFiles/2011/Teo07.MID                  |[Staendchen from Schwannengesang, R245/7 | F. Schubert/F. Liszt]
# Teo        |/MIDIFiles/2011/Teo08.MID                  |[Rhapsody in Blue | George Gershwin]
# Teo        |/MIDIFiles/2011/Teo09.MID                  |[Prelude and Fugue in A Minor, S. 462/1 | J. S. Bach/F. Liszt]
# Teo        |/MIDIFiles/2011/Teo10.MID                  |[Thirty-Two Variations in C Minor, WoO 80 | Ludwig van Beethoven]
# Teo        |/MIDIFiles/2011/Teo11.MID                  |[Berceuse, Op. 57 | Frederic Chopin]
# Teo        |/MIDIFiles/2011/Teo12.MID                  |[Rhapsodie Espagnole S. 254 | Franz Liszt]
# Teo        MIDIFiles/2011/XPMIDI2011/Teo_T_XP.zip
# Teo        MIDIFiles/2011/EnhancedMIDI2011/Teo_T_SMF.zip
# Teo        MIDIFiles/2011/E-SEQ2011/Teo_T_ESEQ.zip
# Wang       |/MIDIFiles/2011/Wang01.MID                 |[Prelude and Fugue in A Minor, WTC II, BWV 889 | J. S. Bach]
# Wang       |/MIDIFiles/2011/Wang02.MID                 |[Sonata No. 7 in D Major, Op. 10 No. 3, 1st mov. | Ludwig van Beethoven]
# Wang       |/MIDIFiles/2011/Wang03.MID                 |[Etude Op. 25 No. 6 in G-sharp Minor | Frederic Chopin]
# Wang       |/MIDIFiles/2011/Wang04.MID                 |[Andante Spianato et Grande Polonaise Brillante, Op. 22 | Frederic Chopin]
# Wang       |/MIDIFiles/2011/Wang05.MID                 |[Impromptu Op. 142 No. 3, in B-flat Major, D935 | Franz Schubert]
# Wang       |/MIDIFiles/2011/Wang06.MID                 |[Transcendental Etude No. 5, "Feux Follets", S. 139/5 | Franz Liszt]
# Wang       |/MIDIFiles/2011/Wang07.MID                 |[Sonata No. 2 in D Minor, Op. 14 | Sergei Prokofiev]
# Wang       |/MIDIFiles/2011/Wang08.MID                 |[Variations Serieuses Op. 54 | Felix Mendelssohn]
# Wang       |/MIDIFiles/2011/Wang09.MID                 |[Jeux d'eau | Maurice Ravel]
# Wang       |/MIDIFiles/2011/Wang10.MID                 |[Night Alley | Ping Gao]
# Wang       |/MIDIFiles/2011/Wang11.MID                 |[Nocturne Op. 9 No. 2 in E-flat Major | Frederic Chopin]
# Wang       |/MIDIFiles/2011/Wang12.MID                 |[Tarantella, S. 162 No. 3 from Venezia e Napoli | Franz Liszt]
# Wang       MIDIFiles/2011/XPMIDI2011/Wang_Z_XP.zip
# Wang       MIDIFiles/2011/EnhancedMIDI2011/Wang_Z_SMF.zip
# Wang       MIDIFiles/2011/E-SEQ2011/Wang_Z_ESEQ.zip
# Yi         |/MIDIFiles/2011/Yi01.MID                   |[Prelude and Fugue in C Minor, WTC II, BWV 871 | J. S. Bach]
# Yi         |/MIDIFiles/2011/Yi02.MID                   |[Sonata No. 23 in F Minor, Op. 57, 1st mov. | Ludwig van Beethoven]
# Yi         |/MIDIFiles/2011/Yi03.MID                   |[Etude Op. 10 No. 4 in C-sharp Minor | Frederic Chopin]
# Yi         |/MIDIFiles/2011/Yi04.MID                   |[Oriental Fantasy "Islamey" | Mily Balakirev]
# Yi         MIDIFiles/2011/XPMIDI2011/Yi_M_XP.zip
# Yi         MIDIFiles/2011/EnhancedMIDI2011/Yi_M_SMF.zip
# Yi         MIDIFiles/2011/E-SEQ2011/Yi_M_ESEQ.zip
# Zhang      |/MIDIFiles/2011/Zhang01.MID                |[Prelude and Fugue in F-sharp Major, WTC I, BWV 858 | J. S. Bach]
# Zhang      |/MIDIFiles/2011/Zhang02.MID                |[Etude Op. 10 No. 12 in C Minor | Frederic Chopin]
# Zhang      |/MIDIFiles/2011/Zhang03.MID                |[Sonata in D Major, K. 311, 1st mov. | Wolfgang Amadeus Mozart]
# Zhang      |/MIDIFiles/2011/Zhang04.MID                |[Scherzo No. 1 in B Minor, Op. 20 | Frederic Chopin]
# Zhang      MIDIFiles/2011/XPMIDI2011/Zhang_Y_XP.zip
# Zhang      MIDIFiles/2011/EnhancedMIDI2011/Zhang_Y_SMF.zip
# Zhang      MIDIFiles/2011/E-SEQ2011/Zhang_Y_ESEQ.zip
# Zhou       |/MIDIFiles/2011/Zhou01.MID                 |[Prelude and Fugue in C-sharp Major, WTC I, BWV 848 | J. S. Bach]
# Zhou       |/MIDIFiles/2011/Zhou02.MID                 |[Sonata E-flat Major, Hob. XVI:49, 1st mov. | Franz Joseph Haydn]
# Zhou       |/MIDIFiles/2011/Zhou03.MID                 |[Etude Op. 10 No. 8 in F Major | Frederic Chopin]
# Zhou       |/MIDIFiles/2011/Zhou04.MID                 |[ABEGG Variations, Op. 1 | Robert Schumann]
# Zhou       |/MIDIFiles/2011/Zhou05.MID                 |[Impromptu Op. 90 No. 1, in C Minor, D899 | Franz Schubert]
# Zhou       |/MIDIFiles/2011/Zhou06.MID                 |[Ballade No. 1 in G Minor, Op. 23 | Frederic Chopin]
# Zhou       |/MIDIFiles/2011/Zhou07.MID                 |[Sonata No. 3 in A Minor, Op. 28 | Sergei Prokofiev]
# Zhou       |/MIDIFiles/2011/Zhou08.MID                 |[Concert Etude No. 3 in D-flat Major, "Un Sospiro", S. 144/3 | Franz Liszt]
# Zhou       |/MIDIFiles/2011/Zhou09.MID                 |[Variations Serieuses Op. 54 | Felix Mendelssohn]
# Zhou       |/MIDIFiles/2011/Zhou10.MID                 |[Jardins sous la pluie from Estampes | Claude Debussy]
# Zhou       |/MIDIFiles/2011/Zhou11.MID                 |[Andante Spianato et Grande Polonaise Brillante, Op. 22 | Frederic Chopin]
# Zhou       MIDIFiles/2011/XPMIDI2011/Zhou_A_XP.zip
# Zhou       MIDIFiles/2011/EnhancedMIDI2011/Zhou_A_SMF.zip
# Zhou       MIDIFiles/2011/E-SEQ2011/Zhou_A_ESEQ.zip
# ([('Ahfat',
#    '/MIDIFiles/2011/Ahfat01.MID',
#    'Prelude and Fugue in D Minor, WTC II, BWV 875'),
#   ('Ahfat',
#    '/MIDIFiles/2011/Ahfat03.MID',
#    'Transcendental Etude No. 7, "Eroica"'),
#   ('Ahfat', '/MIDIFiles/2011/Ahfat04.MID', 'Sonata No. 3 in A Minor, Op. 28'),
#   ('Chon', '/MIDIFiles/2011/Chon01.MID', 'Etude Op. 25 No. 10 in B Minor'),
#   ('Chon',
#    '/MIDIFiles/2011/Chon02.MID',
#    'Prelude and Fugue in G Minor, WTC II, BWV 885'),
#   ('Chon',
#    '/MIDIFiles/2011/Chon03.MID',
#    'Sonata No. 4 in E-flat Major, Op. 7, 1st mov.'),
#   ('Chon', '/MIDIFiles/2011/Chon04.MID', 'Sonata No. 3 in A Minor, Op. 28'),
#   ('Chon',
#    '/MIDIFiles/2011/Chon05.MID',
#    'Impromptu Op. 142 No. 3, in B-flat Major, D935'),
#   ('Chon', '/MIDIFiles/2011/Chon06.MID', 'Choral et Variations'),
#   ('Chon',
#    '/MIDIFiles/2011/Chon07.MID',
#    'Nocturne Op. 27 No. 1 in C-sharp Minor'),
#   ('Chon', '/MIDIFiles/2011/Chon08.MID', 'Polonaise Op. 53 in A-flat Major'),
#   ('Chon',
#    '/MIDIFiles/2011/Chon09.MID',
#    'Thirty-Two Variations in C Minor, WoO 80'),
#   ('Chon', '/MIDIFiles/2011/Chon10.MID', 'Two Polyphonic Pieces'),
#   ('Chon', '/MIDIFiles/2011/Chon11.MID', 'Venezia e Napoli'),
#   ('Colafelice',
#    '/MIDIFiles/2011/Colafelice01.MID',
#    'Prelude and Fugue in D Minor, WTC I, BWV 851'),
#   ('Colafelice',
#    '/MIDIFiles/2011/Colafelice02.MID',
#    'Sonata No. 5 in C Minor, Op. 10 No. 1, 1st mov.'),
#   ('Colafelice',
#    '/MIDIFiles/2011/Colafelice03.MID',
#    'Scherzo No. 4 in E Major, Op. 54'),
#   ('Colafelice',
#    '/MIDIFiles/2011/Colafelice04.MID',
#    'Etude-Tableau, Op. 39 No. 6 in A Minor'),
#   ('Colafelice',
#    '/MIDIFiles/2011/Colafelice05.MID',
#    'Toccata from "Le Tombeau de Couperin"'),
#   ('Colafelice',
#    '/MIDIFiles/2011/Colafelice06.MID',
#    'Visions Fugitives Op. 22'),
#   ('Colafelice',
#    '/MIDIFiles/2011/Colafelice07.MID',
#    'Moment Musical Op. 94 No. 4, in C-sharp Minor, D780'),
#   ('Colafelice',
#    '/MIDIFiles/2011/Colafelice08.MID',
#    'Hungarian Rhapsody No. 10, S. 244/10'),
#   ('Colafelice',
#    '/MIDIFiles/2011/Colafelice09.MID',
#    'Romances Op. 28, Nos. 2 and 3'),
#   ('Colafelice',
#    '/MIDIFiles/2011/Colafelice10.MID',
#    'Variations Serieuses Op. 54'),
#   ('Colafelice',
#    '/MIDIFiles/2011/Colafelice11.MID',
#    'Toccata in D Minor, Op. 11'),
#   ('Colafelice',
#    '/MIDIFiles/2011/Colafelice12.MID',
#    'Trois Mouvements de Petrouchka'),
#   ('Giesbrecht',
#    '/MIDIFiles/2011/Giesbrecht01.MID',
#    'Prelude and Fugue in A Minor, WTC II, BWV889'),
#   ('Giesbrecht',
#    '/MIDIFiles/2011/Giesbrecht02.MID',
#    'Sonata No. 17 in D Minor, Op. 31 No. 2, 1st mov.'),
#   ('Giesbrecht',
#    '/MIDIFiles/2011/Giesbrecht03.MID',
#    'Etude in D-flat Major, Op. 8 No. 10'),
#   ('Giesbrecht', '/MIDIFiles/2011/Giesbrecht04.MID', "L'isle joyeuse"),
#   ('Guo',
#    '/MIDIFiles/2011/Guo01.MID',
#    'Prelude and Fugue in G Minor, WTC II, BWV 885'),
#   ('Guo', '/MIDIFiles/2011/Guo02.MID', 'Etude Op. 25 No. 10 in B Minor'),
#   ('Guo',
#    '/MIDIFiles/2011/Guo03.MID',
#    'Sonata No. 23 in F Minor, Op. 57, 1st mov.'),
#   ('Guo', '/MIDIFiles/2011/Guo04.MID', 'Toccata in D Minor, Op. 11'),
#   ('Hou',
#    '/MIDIFiles/2011/Hou01.MID',
#    'Prelude and Fugue in B Major, WTC II, BWV 892'),
#   ('Hou',
#    '/MIDIFiles/2011/Hou02.MID',
#    'Sonata No. 10 in G Major, Op. 14 No. 2, 1st mov.'),
#   ('Hou', '/MIDIFiles/2011/Hou03.MID', 'Etude Op. 25 No. 12 in C Mnor'),
#   ('Hou', '/MIDIFiles/2011/Hou04.MID', 'Fantasy in B Minor, Op. 28'),
#   ('Hou', '/MIDIFiles/2011/Hou05.MID', 'Rigoletto Paraphrase, S. 434'),
#   ('Hou',
#    '/MIDIFiles/2011/Hou06.MID',
#    'Impromptu Op. 90 No. 3, In G-flat Major, D899'),
#   ('Hou', '/MIDIFiles/2011/Hou07.MID', 'Sonata, Op. 26'),
#   ('Kim',
#    '/MIDIFiles/2011/Kim01.MID',
#    'Prelude from the English Suite No. 2 in A Minor, BWV 807'),
#   ('Kim',
#    '/MIDIFiles/2011/Kim02.MID',
#    'Sonata No. 26 in E-flat Major, Op. 81a, 1st mov.'),
#   ('Kim', '/MIDIFiles/2011/Kim03.MID', 'Etude Op. 25 No. 11 in A Minor'),
#   ('Kim', '/MIDIFiles/2011/Kim04.MID', 'Ballade No. 1 in G Minor, Op. 23'),
#   ('Kim',
#    '/MIDIFiles/2011/Kim05.MID',
#    'Annes de Pelerinage III: Le jeux d\'eau a la Villa d"Este'),
#   ('Kim',
#    '/MIDIFiles/2011/Kim06.MID',
#    'Impromptu Op. 142 No. 3 in B-flat Major, D935'),
#   ('Kim', '/MIDIFiles/2011/Kim07.MID', 'Sonata No. 3 in A Minor, Op. 28'),
#   ('Kim', '/MIDIFiles/2011/Kim08.MID', 'Liebesfreud'),
#   ('Kim',
#    '/MIDIFiles/2011/Kim09.MID',
#    'Thirty-Two Variations in C Minor, WoO 80'),
#   ('Kim', '/MIDIFiles/2011/Kim10.MID', 'Moments Musicaux, Op. 16'),
#   ('Kurz',
#    '/MIDIFiles/2011/Kurz01.MID',
#    'Prelude and Fugue in D Major, WTC II, BWV 874'),
#   ('Kurz',
#    '/MIDIFiles/2011/Kurz02.MID',
#    'Sonata in E-flat Major, Hob. XVI:52, 1st mov.'),
#   ('Kurz',
#    '/MIDIFiles/2011/Kurz03.MID',
#    'Etude Op. 10 No. 4 in C-sharp Minor'),
#   ('Kurz', '/MIDIFiles/2011/Kurz04.MID', 'Scherzo No. 1 in B Minor, Op. 20'),
#   ('Lan',
#    '/MIDIFiles/2011/Lan01.MID',
#    'Prelude and Fugue in F Minor, WTC I, BWV 857'),
#   ('Lan',
#    '/MIDIFiles/2011/Lan02.MID',
#    'Concert Etude No. 2, "La Leggierezza", S. 144/2'),
#   ('Lan',
#    '/MIDIFiles/2011/Lan03.MID',
#    'Sonata in G Major, Hob. XVI:6, 1st mov.'),
#   ('Lan', '/MIDIFiles/2011/Lan04.MID', 'Rondo in A Minor, K. 511'),
#   ('Lee',
#    '/MIDIFiles/2011/Lee01.MID',
#    'Prelude and Fugue in D-flat Major, WTCI, BWV 848'),
#   ('Lee',
#    '/MIDIFiles/2011/Lee02.MID',
#    'Sonata No. 17 in D Minor, Op. 31 No. 2, 1st mov.'),
#   ('Lee', '/MIDIFiles/2011/Lee03.MID', 'ABEGG Variations, Op. 1'),
#   ('Lee',
#    '/MIDIFiles/2011/Lee04.MID',
#    'Concert Etude No. 3 in D-flat Major, "Un Sospiro", S. 144/3'),
#   ('Lin',
#    '/MIDIFiles/2011/Lin01.MID',
#    'Prelude from the English Suite No. 6 in D Minor, BWV 811'),
#   ('Lin',
#    '/MIDIFiles/2011/Lin02.MID',
#    'Sonata Op. 25 No. 5 in F-sharp Minor, 1st mov.'),
#   ('Lin', '/MIDIFiles/2011/Lin03.MID', 'Etude Op. 7 No. 4'),
#   ('Lin', '/MIDIFiles/2011/Lin04.MID', 'Hungarian Rhapsody No. 13, S. 244/13'),
#   ('Lin',
#    '/MIDIFiles/2011/Lin05.MID',
#    'Impromptu Op. 142 No. 3 in B-flat Major, D935'),
#   ('Lin',
#    '/MIDIFiles/2011/Lin06.MID',
#    'Ballade No. 3 in A-flat Major, Op. 47'),
#   ('Lin', '/MIDIFiles/2011/Lin07.MID', 'Choral et Variations'),
#   ('Lou',
#    '/MIDIFiles/2011/Lou01.MID',
#    'Prelude and Fugue in C-sharp Major, WTC I, BWV 848'),
#   ('Lou',
#    '/MIDIFiles/2011/Lou02.MID',
#    'Sonata No. 24 in F-sharp Major, Op. 78'),
#   ('Lou', '/MIDIFiles/2011/Lou03.MID', 'Etudes Op. 10 Nos. 8 and 9'),
#   ('Lou',
#    '/MIDIFiles/2011/Lou04.MID',
#    'In Memoriam to the VIctims of Chernobyl'),
#   ('Lu',
#    '/MIDIFiles/2011/Lu01.MID',
#    'Prelude from the English Suite No. 1 in A Minor, BWV 806'),
#   ('Lu',
#    '/MIDIFiles/2011/Lu02.MID',
#    'Sonata in B-flat Major, K 281, 1st mov.'),
#   ('Lu',
#    '/MIDIFiles/2011/Lu03.MID',
#    'Concert Etude No. 2, "Gnomenreigen", S. 145/2'),
#   ('Lu', '/MIDIFiles/2011/Lu04.MID', 'Excursions Op. 20 Nos. 1, 3 and 4'),
#   ('Lu',
#    '/MIDIFiles/2011/Lu05.MID',
#    'Impromptu Op. 142 No. 4, in F Minor, D935'),
#   ('Lu', '/MIDIFiles/2011/Lu06.MID', 'Nocturne Op. 32 No. 2 in A-flat Major'),
#   ('Lu', '/MIDIFiles/2011/Lu07.MID', 'Sarcasms, Op. 17'),
#   ('Mizumoto',
#    '/MIDIFiles/2011/Mizumoto01.MID',
#    'Sonata in E-flat Major, Hob. XVI: 52, 1st mov.'),
#   ('Mizumoto',
#    '/MIDIFiles/2011/Mizumoto02.MID',
#    'Ballade No. 4 in F Minor, Op. 52'),
#   ('Mizumoto',
#    '/MIDIFiles/2011/Mizumoto03.MID',
#    'Prelude and Fugue in C-sharp Major, WTC I, BWV 848'),
#   ('Mizumoto',
#    '/MIDIFiles/2011/Mizumoto04.MID',
#    'Etude No. 13, "Lescalier du Diable"'),
#   ('Mizumoto',
#    '/MIDIFiles/2011/Mizumoto05.MID',
#    'Elegie in E-flat Minor, Op. 3'),
#   ('Mizumoto',
#    '/MIDIFiles/2011/Mizumoto06.MID',
#    'Sonata No. 23 in F Minor, Op. 57, 1st mov.'),
#   ('Mizumoto',
#    '/MIDIFiles/2011/Mizumoto07.MID',
#    'Impromptu Op. 90, No. 3 in G-flat Major, D899'),
#   ('Mizumoto',
#    '/MIDIFiles/2011/Mizumoto08.MID',
#    'Staendchen, S. 558, No. 9, "Horch, horch! Die Lerch"'),
#   ('Mizumoto', '/MIDIFiles/2011/Mizumoto09.MID', 'Sonata Op. 26, 4th mov.'),
#   ('Mizumoto',
#    '/MIDIFiles/2011/Mizumoto10.MID',
#    'Mazurka Op. 6 No. 2 in C-sharp Minor'),
#   ('Mizumoto',
#    '/MIDIFiles/2011/Mizumoto11.MID',
#    'Thirty-Two Variations in C Minor, WoO 80'),
#   ('Mizumoto',
#    '/MIDIFiles/2011/Mizumoto12.MID',
#    'Sonata No. 2 in B-flat Minor, Op. 36 (1913)'),
#   ('Ozaki',
#    '/MIDIFiles/2011/Ozaki01.MID',
#    'Prelude and Fugue in E Major, WTC I, BWV 854'),
#   ('Ozaki',
#    '/MIDIFiles/2011/Ozaki02.MID',
#    'Sonata in D Major, K. 284, 1st mov.'),
#   ('Ozaki',
#    '/MIDIFiles/2011/Ozaki03.MID',
#    'Etude in G-sharp Minor, Op. 25 No. 6'),
#   ('Ozaki',
#    '/MIDIFiles/2011/Ozaki04.MID',
#    'Concert Etude No. 2, "La Leggierezza", S. 144/2'),
#   ('Ozaki',
#    '/MIDIFiles/2011/Ozaki05.MID',
#    'Hungarian Rhapsody No. 12, S. 244/12'),
#   ('Ozaki',
#    '/MIDIFiles/2011/Ozaki06.MID',
#    'Prelude in G-sharp Minor, Op. 32 No. 12'),
#   ('Ozaki',
#    '/MIDIFiles/2011/Ozaki07.MID',
#    'Impromptu Op. 142 No. 1, in F Minor, D935'),
#   ('Ozaki', '/MIDIFiles/2011/Ozaki08.MID', 'Die Forelle'),
#   ('Ozaki',
#    '/MIDIFiles/2011/Ozaki09.MID',
#    'Variations in B-flat Minor, Op. 3'),
#   ('Ozaki',
#    '/MIDIFiles/2011/Ozaki10.MID',
#    'Sonata in B-flat Major, Hob. XVI:41'),
#   ('Ozaki', '/MIDIFiles/2011/Ozaki11.MID', 'Variations Serieuses, Op. 54'),
#   ('Ozaki',
#    '/MIDIFiles/2011/Ozaki12.MID',
#    "Scherzo from A Midsummer Night's Dream"),
#   ('Ozaki', '/MIDIFiles/2011/Ozaki13.MID', 'In the Garden , Etude-Idyll'),
#   ('Ozaki', '/MIDIFiles/2011/Ozaki14.MID', 'Danse Macabre S.555/R.240'),
#   ('Rizikov',
#    '/MIDIFiles/2011/Rizikov01.MID',
#    'Prelude and Fugue in A Minor, WTC I, BWV 865'),
#   ('Rizikov',
#    '/MIDIFiles/2011/Rizikov02.MID',
#    'Sonata No. 17 in D Minor, Op. 31 No. 2, 1st mov.'),
#   ('Rizikov',
#    '/MIDIFiles/2011/Rizikov03.MID',
#    'Etude Op. 10 No. 8 in F Major'),
#   ('Rizikov', '/MIDIFiles/2011/Rizikov04.MID', 'Rondo in C Minor, Op. 1'),
#   ('Sham',
#    '/MIDIFiles/2011/Sham01.MID',
#    'Prelude and Fugue in B-flat Minor, WTC I, BWV 867'),
#   ('Sham', '/MIDIFiles/2011/Sham02.MID', 'Etude Op. 25 No. 11 in A Minor'),
#   ('Sham',
#    '/MIDIFiles/2011/Sham03.MID',
#    'Sonata No. 26 in E-flat Major, Op. 81a, 1st mov.'),
#   ('Sham',
#    '/MIDIFiles/2011/Sham04.MID',
#    'Rondo Capriccioso in E Minor, Op. 14'),
#   ('Sham', '/MIDIFiles/2011/Sham05.MID', 'Ballade No. 2 in B Minor, S. 171'),
#   ('Sham',
#    '/MIDIFiles/2011/Sham06.MID',
#    'Impromptu Op. 90 No. 3, in G-flat Major, D899'),
#   ('Sham', '/MIDIFiles/2011/Sham07.MID', 'Trois Pieces pour Piano'),
#   ('Sham', '/MIDIFiles/2011/Sham08.MID', 'Variations Serieuses, Op. 54'),
#   ('Sham', '/MIDIFiles/2011/Sham09.MID', 'Sonata No. 6 in A Major, Op. 82'),
#   ('Shychko',
#    '/MIDIFiles/2011/Shychko01.MID',
#    'Prelude and Fugue in G-sharp Minor, WTC I, BWV 863'),
#   ('Shychko',
#    '/MIDIFiles/2011/Shychko02.MID',
#    'Sonata No. 21 in C Major, Op. 53, 1st mov.'),
#   ('Shychko',
#    '/MIDIFiles/2011/Shychko03.MID',
#    'Etude Op. 25 No. 11 in A Minor'),
#   ('Shychko',
#    '/MIDIFiles/2011/Shychko04.MID',
#    'Two Preludes from Op. 28, Nos. 15 and 24'),
#   ('Sladek',
#    '/MIDIFiles/2011/Sladek01.MID',
#    'Prelude and Fugue in D Major, WTC I, BWV 850'),
#   ('Sladek',
#    '/MIDIFiles/2011/Sladek02.MID',
#    'Sonata No. 21 in C Major, Op. 53, 1st mov.'),
#   ('Sladek',
#    '/MIDIFiles/2011/Sladek03.MID',
#    'Etude Op. 10 No. 4 in C-sharp Minor'),
#   ('Sladek',
#    '/MIDIFiles/2011/Sladek04.MID',
#    'Ballade No. 1 in G Minor, Op. 23'),
#   ('Song',
#    '/MIDIFiles/2011/Song01.MID',
#    'Prelude and Fugue in E-flat Major, WTC II, BWV 876'),
#   ('Song', '/MIDIFiles/2011/Song02.MID', 'Etude Op. 25 No. 11 in A Minor'),
#   ('Song',
#    '/MIDIFiles/2011/Song03.MID',
#    'Sonata No. 21 in C Major, Op. 53, 1st mov.'),
#   ('Song', '/MIDIFiles/2011/Song04.MID', 'Toccata in D Minor, Op. 11'),
#   ('Teo',
#    '/MIDIFiles/2011/Teo01.MID',
#    'Prelude and Fugue in A Minor, WTC I, BWV 865'),
#   ('Teo',
#    '/MIDIFiles/2011/Teo02.MID',
#    'Sonata No. 23 in F Minor, Op. 57, 1st mov.'),
#   ('Teo', '/MIDIFiles/2011/Teo03.MID', 'Alborada del grcioso from Miroirs'),
#   ('Teo',
#    '/MIDIFiles/2011/Teo04.MID',
#    '"Toccatina" Concert Etude Op. 40 No. 3'),
#   ('Teo',
#    '/MIDIFiles/2011/Teo05.MID',
#    'Impromptu Op. 90 No. 1, in C Minor, D899'),
#   ('Teo', '/MIDIFiles/2011/Teo06.MID', 'Toccata in D Minor, Op. 11'),
#   ('Teo',
#    '/MIDIFiles/2011/Teo07.MID',
#    'Staendchen from Schwannengesang, R245/7'),
#   ('Teo', '/MIDIFiles/2011/Teo08.MID', 'Rhapsody in Blue'),
#   ('Teo',
#    '/MIDIFiles/2011/Teo09.MID',
#    'Prelude and Fugue in A Minor, S. 462/1'),
#   ('Teo',
#    '/MIDIFiles/2011/Teo10.MID',
#    'Thirty-Two Variations in C Minor, WoO 80'),
#   ('Teo', '/MIDIFiles/2011/Teo11.MID', 'Berceuse, Op. 57'),
#   ('Teo', '/MIDIFiles/2011/Teo12.MID', 'Rhapsodie Espagnole S. 254'),
#   ('Wang',
#    '/MIDIFiles/2011/Wang01.MID',
#    'Prelude and Fugue in A Minor, WTC II, BWV 889'),
#   ('Wang',
#    '/MIDIFiles/2011/Wang02.MID',
#    'Sonata No. 7 in D Major, Op. 10 No. 3, 1st mov.'),
#   ('Wang',
#    '/MIDIFiles/2011/Wang03.MID',
#    'Etude Op. 25 No. 6 in G-sharp Minor'),
#   ('Wang',
#    '/MIDIFiles/2011/Wang04.MID',
#    'Andante Spianato et Grande Polonaise Brillante, Op. 22'),
#   ('Wang',
#    '/MIDIFiles/2011/Wang05.MID',
#    'Impromptu Op. 142 No. 3, in B-flat Major, D935'),
#   ('Wang',
#    '/MIDIFiles/2011/Wang06.MID',
#    'Transcendental Etude No. 5, "Feux Follets", S. 139/5'),
#   ('Wang', '/MIDIFiles/2011/Wang07.MID', 'Sonata No. 2 in D Minor, Op. 14'),
#   ('Wang', '/MIDIFiles/2011/Wang08.MID', 'Variations Serieuses Op. 54'),
#   ('Wang', '/MIDIFiles/2011/Wang09.MID', "Jeux d'eau"),
#   ('Wang', '/MIDIFiles/2011/Wang10.MID', 'Night Alley'),
#   ('Wang',
#    '/MIDIFiles/2011/Wang11.MID',
#    'Nocturne Op. 9 No. 2 in E-flat Major'),
#   ('Wang',
#    '/MIDIFiles/2011/Wang12.MID',
#    'Tarantella, S. 162 No. 3 from Venezia e Napoli'),
#   ('Yi',
#    '/MIDIFiles/2011/Yi01.MID',
#    'Prelude and Fugue in C Minor, WTC II, BWV 871'),
#   ('Yi',
#    '/MIDIFiles/2011/Yi02.MID',
#    'Sonata No. 23 in F Minor, Op. 57, 1st mov.'),
#   ('Yi', '/MIDIFiles/2011/Yi03.MID', 'Etude Op. 10 No. 4 in C-sharp Minor'),
#   ('Yi', '/MIDIFiles/2011/Yi04.MID', 'Oriental Fantasy "Islamey"'),
#   ('Zhang',
#    '/MIDIFiles/2011/Zhang01.MID',
#    'Prelude and Fugue in F-sharp Major, WTC I, BWV 858'),
#   ('Zhang', '/MIDIFiles/2011/Zhang02.MID', 'Etude Op. 10 No. 12 in C Minor'),
#   ('Zhang',
#    '/MIDIFiles/2011/Zhang03.MID',
#    'Sonata in D Major, K. 311, 1st mov.'),
#   ('Zhang', '/MIDIFiles/2011/Zhang04.MID', 'Scherzo No. 1 in B Minor, Op. 20'),
#   ('Zhou',
#    '/MIDIFiles/2011/Zhou01.MID',
#    'Prelude and Fugue in C-sharp Major, WTC I, BWV 848'),
#   ('Zhou',
#    '/MIDIFiles/2011/Zhou02.MID',
#    'Sonata E-flat Major, Hob. XVI:49, 1st mov.'),
#   ('Zhou', '/MIDIFiles/2011/Zhou03.MID', 'Etude Op. 10 No. 8 in F Major'),
#   ('Zhou', '/MIDIFiles/2011/Zhou04.MID', 'ABEGG Variations, Op. 1'),
#   ('Zhou',
#    '/MIDIFiles/2011/Zhou05.MID',
#    'Impromptu Op. 90 No. 1, in C Minor, D899'),
#   ('Zhou', '/MIDIFiles/2011/Zhou06.MID', 'Ballade No. 1 in G Minor, Op. 23'),
#   ('Zhou', '/MIDIFiles/2011/Zhou07.MID', 'Sonata No. 3 in A Minor, Op. 28'),
#   ('Zhou',
#    '/MIDIFiles/2011/Zhou08.MID',
#    'Concert Etude No. 3 in D-flat Major, "Un Sospiro", S. 144/3'),
#   ('Zhou', '/MIDIFiles/2011/Zhou09.MID', 'Variations Serieuses Op. 54'),
#   ('Zhou',
#    '/MIDIFiles/2011/Zhou10.MID',
#    'Jardins sous la pluie from Estampes'),
#   ('Zhou',
#    '/MIDIFiles/2011/Zhou11.MID',
#    'Andante Spianato et Grande Polonaise Brillante, Op. 22')],
#  [('Ahfat', 'MIDIFiles/2011/XPMIDI2011/Ahfat_K_XP.zip'),
#   ('Ahfat', 'MIDIFiles/2011/EnhancedMIDI2011/Ahfat_K_SMF.zip'),
#   ('Ahfat', 'MIDIFiles/2011/E-SEQ2011/Ahfat_K_ESEQ.zip'),
#   ('Chon', 'MIDIFiles/2011/XPMIDI2011/Chon_S_XP.zip'),
#   ('Chon', 'MIDIFiles/2011/EnhancedMIDI2011/Chon_S_SMF.zip'),
#   ('Chon', 'MIDIFiles/2011/E-SEQ2011/Chon_S_ESEQ.zip'),
#   ('Colafelice', 'MIDIFiles/2011/XPMIDI2011/Colafelice_L_XP.zip'),
#   ('Colafelice', 'MIDIFiles/2011/EnhancedMIDI2011/Colafelice_L_SMF.zip'),
#   ('Colafelice', 'MIDIFiles/2011/E-SEQ2011/Colafelice_L_ESEQ.zip'),
#   ('Giesbrecht', 'MIDIFiles/2011/XPMIDI2011/Giesbrect_R_XP.zip'),
#   ('Giesbrecht', 'MIDIFiles/2011/EnhancedMIDI2011/Giesbrecht_R_SMF.zip'),
#   ('Giesbrecht', 'MIDIFiles/2011/E-SEQ2011/Giesbrecht_R_ESEQ.zip'),
#   ('Guo', 'MIDIFiles/2011/XPMIDI2011/Guo_Z_XP.zip'),
#   ('Guo', 'MIDIFiles/2011/EnhancedMIDI2011/Guo_Z_SMF.zip'),
#   ('Guo', 'MIDIFiles/2011/E-SEQ2011/Guo_Z_ESEQ.zip'),
#   ('Hou', 'MIDIFiles/2011/XPMIDI2011/Hou_K_XP.zip'),
#   ('Hou', 'MIDIFiles/2011/EnhancedMIDI2011/Hou_K_SMF.zip'),
#   ('Hou', 'MIDIFiles/2011/E-SEQ2011/Hou_K_ESEQ.zip'),
#   ('Kim', 'MIDIFiles/2011/XPMIDI2011/Kim_S_XP.zip'),
#   ('Kim', 'MIDIFiles/2011/EnhancedMIDI2011/Kim_S_SMF.zip'),
#   ('Kim', 'MIDIFiles/2011/E-SEQ2011/Kim_S_ESEQ.zip'),
#   ('Kurz', 'MIDIFiles/2011/XPMIDI2011/Kurz_A_XP.zip'),
#   ('Kurz', 'MIDIFiles/2011/EnhancedMIDI2011/Kurz_A_SMF.zip'),
#   ('Kurz', 'MIDIFiles/2011/E-SEQ2011/Kurz_A_ESEQ.zip'),
#   ('Lan', 'MIDIFiles/2011/XPMIDI2011/Lan_B_XP.zip'),
#   ('Lan', 'MIDIFiles/2011/EnhancedMIDI2011/Lan_B_SMF.zip'),
#   ('Lan', 'MIDIFiles/2011/E-SEQ2011/Lan_B_ESEQ.zip'),
#   ('Lee', 'MIDIFiles/2011/XPMIDI2011/Lee_C_XP.zip'),
#   ('Lee', 'MIDIFiles/2011/EnhancedMIDI2011/Lee_C_SMF.zip'),
#   ('Lee', 'MIDIFiles/2011/E-SEQ2011/Lee_C_ESEQ.zip'),
#   ('Lin', 'MIDIFiles/2011/XPMIDI2011/Lin_P_XP.zip'),
#   ('Lin', 'MIDIFiles/2011/EnhancedMIDI2011/Lin_P_SMF.zip'),
#   ('Lin', 'MIDIFiles/2011/E-SEQ2011/Lin_P_ESEQ.zip'),
#   ('Lou', 'MIDIFiles/2011/XPMIDI2011/Lou_V_XP.zip'),
#   ('Lou', 'MIDIFiles/2011/EnhancedMIDI2011/Lou_V_SMF.zip'),
#   ('Lou', 'MIDIFiles/2011/E-SEQ2011/Lou_V_ESEQ.zip'),
#   ('Lu', 'MIDIFiles/2011/XPMIDI2011/Lu_X_XP.zip'),
#   ('Lu', 'MIDIFiles/2011/EnhancedMIDI2011/Lu_X_SMF.zip'),
#   ('Lu', 'MIDIFiles/2011/E-SEQ2011/Lu_X_ESEQ.zip'),
#   ('Mizumoto', 'MIDIFiles/2011/XPMIDI2011/Mizumoto_W_XP.zip'),
#   ('Mizumoto', 'MIDIFiles/2011/EnhancedMIDI2011/Mizumoto_W_SMF.zip'),
#   ('Mizumoto', 'MIDIFiles/2011/E-SEQ2011/Mizumoto_W_ESEQ.zip'),
#   ('Ozaki', 'MIDIFiles/2011/XPMIDI2011/Ozaki_M_XP.zip'),
#   ('Ozaki', 'MIDIFiles/2011/EnhancedMIDI2011/Ozaki_M_SMF.zip'),
#   ('Ozaki', 'MIDIFiles/2011/E-SEQ2011/Ozaki_M_ESEQ.zip'),
#   ('Rizikov', 'MIDIFiles/2011/XPMIDI2011/Rizikov_A_XP.zip'),
#   ('Rizikov', 'MIDIFiles/2011/EnhancedMIDI2011/Rizikov_A_SMF.zip'),
#   ('Rizikov', 'MIDIFiles/2011/E-SEQ2011/Rizikov_A_ESEQ.zip'),
#   ('Sham', 'MIDIFiles/2011/XPMIDI2011/Sham_A_XP.zip'),
#   ('Sham', 'MIDIFiles/2011/EnhancedMIDI2011/Sham_A_SMF.zip'),
#   ('Sham', 'MIDIFiles/2011/E-SEQ2011/Sham_A_ESEQ.zip'),
#   ('Shychko', 'MIDIFiles/2011/XPMIDI2011/Shychko_A_XP.zip'),
#   ('Shychko', 'MIDIFiles/2011/EnhancedMIDI2011/Shychko_A_SMF.zip'),
#   ('Shychko', 'MIDIFiles/2011/E-SEQ2011/Shychko_A_ESEQ.zip'),
#   ('Sladek', 'MIDIFiles/2011/XPMIDI2011/Sladek_J_XP.zip'),
#   ('Sladek', 'MIDIFiles/2011/EnhancedMIDI2011/Sladek_J_SMF.zip'),
#   ('Sladek', 'MIDIFiles/2011/E-SEQ2011/Sladek_J_ESEQ.zip'),
#   ('Song', 'MIDIFiles/2011/XPMIDI2011/Song_Z_XP.zip'),
#   ('Song', 'MIDIFiles/2011/EnhancedMIDI2011/Song_Z_SMF.zip'),
#   ('Song', 'MIDIFiles/2011/E-SEQ2011/Song_Z_ESEQ.zip'),
#   ('Teo', 'MIDIFiles/2011/XPMIDI2011/Teo_T_XP.zip'),
#   ('Teo', 'MIDIFiles/2011/EnhancedMIDI2011/Teo_T_SMF.zip'),
#   ('Teo', 'MIDIFiles/2011/E-SEQ2011/Teo_T_ESEQ.zip'),
#   ('Wang', 'MIDIFiles/2011/XPMIDI2011/Wang_Z_XP.zip'),
#   ('Wang', 'MIDIFiles/2011/EnhancedMIDI2011/Wang_Z_SMF.zip'),
#   ('Wang', 'MIDIFiles/2011/E-SEQ2011/Wang_Z_ESEQ.zip'),
#   ('Yi', 'MIDIFiles/2011/XPMIDI2011/Yi_M_XP.zip'),
#   ('Yi', 'MIDIFiles/2011/EnhancedMIDI2011/Yi_M_SMF.zip'),
#   ('Yi', 'MIDIFiles/2011/E-SEQ2011/Yi_M_ESEQ.zip'),
#   ('Zhang', 'MIDIFiles/2011/XPMIDI2011/Zhang_Y_XP.zip'),
#   ('Zhang', 'MIDIFiles/2011/EnhancedMIDI2011/Zhang_Y_SMF.zip'),
#   ('Zhang', 'MIDIFiles/2011/E-SEQ2011/Zhang_Y_ESEQ.zip'),
#   ('Zhou', 'MIDIFiles/2011/XPMIDI2011/Zhou_A_XP.zip'),
#   ('Zhou', 'MIDIFiles/2011/EnhancedMIDI2011/Zhou_A_SMF.zip'),
#   ('Zhou', 'MIDIFiles/2011/E-SEQ2011/Zhou_A_ESEQ.zip')])
