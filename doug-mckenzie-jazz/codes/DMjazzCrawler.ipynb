# %%
import requests
from bs4 import BeautifulSoup
import os
import sys
import time
import json
import re

# %%
class DMjazzCrawler():
    BASE_URL = 'http://www.bushgrafts.com/jazz'
    ROOT = 'archive'
    
    def __init__(self, sleep_time=0.1, log=True):
        self.sleep_time = sleep_time
        self.log = log

    def _request_url(self, url, doctype='html'):
        # set header
        response = requests.get(url, headers = {"Cache-Control":"max-age=0"})

        # sleep
        time.sleep(self.sleep_time)

        # return
        if doctype =='html':
            soup = BeautifulSoup(response.text, 'html.parser')
            return soup
        elif  doctype =='content':
            return response.content
        else:
            return response

    def _log_print(self, log, quite=False):
        if not quite:
            print(log)

        if self.log:
            with open("log.txt", "a") as f:
                print(log, file=f)
    
    def fetch_song(self):
        self.soup = self._request_url(self.BASE_URL+'/midi.htm')
        a_list = dmc.soup.find_all('a')
        midi_list = []
        name_list = []

        cnt = 0
        for idx, a in enumerate(a_list):
            str_ = a.get('href')
            if str_ and (str_ not in midi_list) and ('.mid' in str_):
                song_name = re.sub( '\s+', ' ' , a.text.replace( '\r\n' ,  '' )).strip(' ')
                if song_name:
                    midi_fn = str_.split('/')[1]
                    midi_list.append(midi_fn )
                    name_list.append(song_name)
                    print('%3d | %-40s %s'%(idx, song_name, midi_fn))
                    cnt += 1

        self._log_print('Total: %d'%cnt)
        
        return dict(zip(midi_list, name_list))
    
    def crawl_song(self, song_dict):
        for idx, k in enumerate(song_dict.keys()):
   
            url = self.BASE_URL + '/Midi%20site/' + k
            print('%3d %s' %(idx, url))
            content = self._request_url(url, doctype='content')
            
            with open(os.path.join(self.ROOT,k), "wb") as f:
                f.write(content)
            
    def run(self):
        
        song_dict = self.fetch_song()
        
        if not os.path.exists(self.ROOT):
            os.makedirs(self.ROOT)
        with open(os.path.join(self.ROOT, 'archive.json'), "w") as f:
                json.dump(song_dict, f)
        
        self.crawl_song(song_dict)

# %%
dmc = DMjazzCrawler()
dmc.run()
# Out:
#  33 | A Fine Romance - take 1                  afine-1.mid
#  35 | A Fine Romance - take 2                  afine-2.mid
#  36 | A Ghost Of A Chance                      Aghostofachance.mid
#  37 | A House Is Not A Home                    AHouseis.mid
#  38 | A Nightingale Sang...                    Anighting.mid
#  39 | A Remark You Made                        ARemarkYouMade.mid
#  40 | A Sleepin' Bee                           A Sleepin' Bee.mid
#  41 | After You've Gone                        AfterYou.mid
#  42 | Alfie                                    alfiepno.mid
#  43 | Alice In Wonderland                      AliceInWonderland.mid
#  44 | All The Things You Are                   AllTheThings V2.mid
#  45 | All The Things You Are/2                 All The Things You Are.mid
#  46 | All The Things Reharmonized              AllTheThings Reharmonized.mid
#  47 | Alone Together (trio)                    Alone Together.mid
#  49 | Ask Me Now (Monk)                        Ask Me Now 2.mid
#  50 | Ave Maria                                Bach Prelude No 1 (Ave Maria).mid
#  51 | Autumn In New York                       Autumn In NY.mid
#  52 | Autumn Leaves                            AutumnLeaves.mid
#  55 | Baby It's Cold Outside                   Baby its Cold outside.mid
#  57 | Beautiful Love                           Beautiful Love (Doug McKenzie).mid
#  58 | Beethoven Pathetique                     Pathetique.mid
#  59 | Begin The Beguine                        Begin The Beguine.mid
#  60 | Bess You Is...                           Bess You Is.mid
#  61 | Blackbird                                Blackbird (Brad Mehldau).mid
#  62 | Blame It On My Youth                     Blameiton.mid
#  63 | Blue Bossa (tk1)                         BlueBossa1GM.mid
#  64 | Blue Bossa (tk2)                         BlueBossa3GM.mid
#  65 | Blue Room                                Blue room midi file.mid
#  66 | Brazilian Like                           Brazillike.mid
#  67 | Brazilian Suite                          BrazilianSuite.mid
#  68 | Broadway                                 broadway.mid
#  69 | But Beautiful                            But Beautifulsolo.mid
#  70 | By Myself                                Bymyself.mid
#  71 | By Myself /2                             By Myself3.mid
#  73 | By The Time I Get...                     By The Time.mid
#  76 | Cantabile                                Cantabile 2.mid
#  77 | Caravan (trio)                           Caravan2.mid
#  78 | Carnival (Black Orpheus)                 Carnival.mid
#  80 | Cast Your Fate...                        Cast Your Fate.mid
#  81 | Chelsea Bridge                           Chelsea Bridge.mid
#  82 | Chopin Waltz                             Chopin WaltzAb.mid
#  83 | Cinema Paradiso                          cinema.mid
#  84 | Close Your Eyes                          Close your eyes.mid
#  85 | Come Rain Or Come Shine (solo)           Come Rain or Come Shine V1.mid
#  86 | Come Rain Or Come Shine (duet)           Come Rain or Come Shine duo.mid
#  87 | Come Sunday                              comesun.mid
#  88 | Cry Me A River                           Cry me a river.mid
#  89 | Cubano Chant                             Cubano Chant 2.mid
#  92 | Dancing On The Ceiling                   DancingontheCeiling.mid
#  93 | Danny Boy                                Dannyboy.mid
#  94 | Day Dream                                Day Dream.mid
#  95 | Days Of Wine And Roses                   DaysofWine.mid
#  96 | Dearly Beloved                           dearlybeloved.mid
#  97 | Deep Purple                              DeepPurple.mid
#  98 | Desafinado                               Desafinado.mid
# 100 | Desire                                   desire.mid
# 101 | Detour Ahead                             Detour ahead.mid
# 102 | Do I Love You Because...                 Do I Love You Because you're Beautiful.mid
# 103 | Dolphin Dance                            dolphindance3.mid
# 104 | Don't Explain                            Don't Explain solo.mid
# 105 | Dreamsville                              Dreamsville.mid
# 108 | Easy Does It [M]                         Easy does it.mid
# 109 | Easy Living [M]                          Easy Living 3.mid
# 110 | Easy To Love                             EasytoLove2.mid
# 111 | Effendi                                  Effendi - McCoy Tyner.mid
# 112 | Eleanor Rigby                            Eleanor Rigby.mid
# 114 | Emily                                    emily.mid
# 116 | Estate                                   estate.mid
# 117 | Exactly Like You                         Exactly Like You.mid
# 121 | Falling Grace                            Falling Grace .mid
# 122 | Falling In Love With Love (trio)         Falling in Love with Love trio.mid
# 124 | For Sentimental Reasons                  ForSentimentalReasons.mid
# 127 | Gaviota                                  Gaviota trio 2.mid
# 128 | Georgia On My Mind                       Georgia.mid
# 129 | Girl Talk                                GirlTalk.mid
# 130 | Give Me The Simple Life                  simplelife.mid
# 131 | Goin' Home                               Goin'_Home_(Real_Time)_(Antonin_Dvorak).mid
# 132 | Good Bait                                goodbait.mid
# 133 | Good Bait                                GoodBaitPiano.mid
# 134 | Good Bait                                goodbaitGM.mid
# 135 | Gone With The Wind                       gonewind.mid
# 136 | Gone With The Wind (II) [M]              Gone with the wind.mid
# 137 | Green Dolphin Street                     Green Dolph solo.mid
# 138 | Gymnopedie/Medley                        Gymnopedie-It Never Entered My Mind.mid
# 141 | Have You Met Miss Jones (duet)           Have You Met - duet.mid
# 142 | Have You Met Miss Jones (latin)          Have You Met Miss Jones - latin.mid
# 143 | How Come You Like Me...                  HowkumU.mid
# 145 | How Deep Is The Ocean (old)              How Deep is the Ocean (Doug McKenzie).mid
# 146 | How Deep Is The Ocean (solo)             howdsolo.mid
# 147 | How Deep Is The Ocean (trio)             hwdptrio.mid
# 148 | Hymn To Freedom                          Hymn To Freedom.mid
# 151 | I'm Old Fashioned (trio) [M]             oldfashionedtrio.mid
# 152 | I Can't Get Started                      Icantgetstarted.mid
# 153 | I Could Write A Book                     couldwrite.mid
# 154 | I Concentrate On You                     I Concentrate on You.mid
# 155 | I Cover The Waterfront                   I Cover the Waterfront - solo.mid
# 156 | I Fall In Love Too Easily                I fall in Love Too Easily.mid
# 157 | I Fall In Love Too Easily                I Fall in Love v2.mid
# 158 | I Hear A Rhapsody                        I Hear a Rhapsody.mid
# 159 | I'll Close My Eyes (trio)                I'll Close My Eyes 2.mid
# 161 | I Love's You Porgy /1 [M]                porgy1.mid
# 162 | I Love's You Porgy /2 [M]                porgy2.mid
# 163 | I Never Knew                             INeverKnew.mid
# 164 | I Remember Clifford (tk1)                Clifford1.mid
# 165 | I Remember Clifford (tk 2)               Clifford2.mid
# 166 | I Remember You (solo) [M]                Irememberyousolo.mid
# 167 | I Should Care                            McKenzie-Ishouldcare2.mid
# 168 | I Should Care / take 2                   ishouldcare2.mid
# 169 | I Thought About You                      I Thought About You (Doug McKenzie).mid
# 170 | I Want To Be Happy                       IWantToBeHappyXG.mid
# 171 | If Ever I Should Leave You               If Ever I should leave You.mid
# 172 | If I Loved You                           if i loved you.mid
# 173 | If I Should Leave You                    IfIshouldLeaveYou.mid
# 174 | If I Were A Bell                         IfIwere.mid
# 175 | I'm Confessin'                           I'm Confessin' - solo.mid
# 176 | I'm Old Fashioned                        I'mOldFash.mid
# 177 | I'm Old Fashioned (tk 2)                 ImOldFash.mid
# 178 | In A Sentimental Mood                    Inasent.mid
# 180 | Indiana                                  Indiana.mid
# 181 | In Your Own Sweet Way (tk1)              SweetWay1.mid
# 182 | In Your Own Sweet Way (tk2)              SweetWay2.mid
# 183 | In Your Own Sweet Way (tk3)              SweetWay3.mid
# 184 | Isfahan (Elf)                            Isfahan (Elf).mid
# 185 | Isn't It Romantic [M]                    Isn_t_it_Romantic.mid
# 186 | It Could Happen To You                   It Could Happen V2.mid
# 187 | It Could Happen To You (trio) [M]        It Could Happen - piano trio.mid
# 188 | It Could Happen To You                   ItCouldHappenGM.mid
# 189 | It Don't Mean A Thing... [M]             Itdon'tmeanathing.mid
# 190 | It's Easy To Remember                    Its Easy to Remember.mid
# 191 | It Might As Well Be Spring               It Might as well be Spring v2.mid
# 193 | It's The Talk Of The Town                Its theTalk Of The Town - solo.mid
# 194 | I've Grown Accustomed...                 accustomed.mid
# 197 | Just A Gigolo                            Just a Gigolo.mid
# 198 | Just Friends                             justfrien solo.mid
# 199 | Just Friends (trio)                      Just Friends Trio.mid
# 200 | Just You, Just Me                        justyou_mark.mid
# 203 | Ladies In Mercedes                       Ladies in Mercedes.mid
# 204 | Lady Be Good                             ladybegood.mid
# 205 | Laura                                    laura.mid
# 206 | Les Grelots (Petrucciani)                grelots.mid
# 208 | Like Being In Love                       It'sAlmostLikeBeingInLove.mid
# 209 | Little Girl Blue                         Little Girl Blue.mid
# 210 | Long Ago And Far Away [M]                Long Ago and Far away - 3 versions.mid
# 211 | Look For The Silver Lining [M]           LookfortheSilverLining.mid
# 212 | Louisiana                                louisiana.mid
# 213 | Love Letters                             love letters.mid
# 214 | Love Walked In                           Love walked In.mid
# 215 | Love Walked In                           LoveWalked.mid
# 216 | Lover Come Back...                       lovercome piano.mid
# 217 | Lullaby                                  Lullaby.mid
# 219 | Lush Life                                LushLife  trio.mid
# 222 | Mad About The Boy                        Mad About the Boy.mid
# 223 | Maiden Voyage                            maidenvoyage.mid
# 224 | Maid(en)s Of Cadiz                       Maids of Cadiz 2.mid
# 225 | Make Someone Happy                       Make Someone Happy.mid
# 226 | Manteca                                  manteca.mid
# 227 | Mean To Me                               Mean to Me (Doug McKenzie).mid
# 228 | Medley "The King And I"                  KingandI.mid
# 229 | Memories Of Paris                        Memories of Paris.mid
# 230 | Merry Christmas                          merryxmas.mid
# 231 | Mike Pee                                 Mike Pee 2.mid
# 233 | Milestones                               milestones.mid
# 234 | Miyako                                   Miyako.mid
# 235 | Mood Indigo                              Mood Indigo - solo.mid
# 236 | Moon And Sand                            Moon and Sand.mid
# 237 | Moon River                               Moon River 3.mid
# 239 | Moonlight In Vermont                     moonlightinvermont.mid
# 240 | My Foolish Heart                         MyFoolishHeart.mid
# 241 | My Funny Valentine                       MyFunny3.mid
# 242 | My Funny Valentine (solo)                funny val solo.mid
# 244 | My Heart Stood Still                     myheartstoodstill edited a bit.mid
# 245 | My Man's Gone Now                        ManGone.mid
# 247 | My One And Only Love                     Myoneand.mid
# 248 | My Romance                               My Romance.mid
# 249 | My Shining Hour                          My Shining Hour.mid
# 250 | My Shining Hour (solo)                   MyShiningHoursolo.mid
# 251 | My Ship                                  My ship solo.mid
# 254 | Nardis                                   Nardis.mid
# 256 | New Orleans                              NewOrleans.mid
# 257 | Nocturne In Eb                           NocturneEbChopin.mid
# 260 | Old Folks                                Old Folks.mid
# 261 | Old Man River                            Old Man River.mid
# 262 | Once Upon A Summertime                   Once upon a summertime.mid
# 263 | On Green Dolphin Street                  On Green Dolphin 4.mid
# 264 | Our Love Is Here To Stay (trio)          loveishere to stay.mid
# 265 | Out Of Nowhere (1)                       Out of Nowhere 1.mid
# 266 | Out Of Nowhere (2)                       Out of Nowhere 2.mid
# 267 | Out Of Nowhere (3)                       Out of Nowhere 3.mid
# 268 | Over The Rainbow (trio)                  Over the rain trio.mid
# 269 | Over The Rainbow (GM)                    OverTheRainbowGM.mid
# 270 | Over The Rainbow (XG)                    OverTheRainbowXG.mid
# 274 | Pent Up House                            pentupHouse.mid
# 275 | Penthouse Serenade                       penthouse s.mid
# 276 | People Will Say We're In Love            People Will Say We're in Love2.mid
# 277 | Periscope                                periscope.mid
# 278 | Pick Yourself                            Pick yourself.mid
# 279 | Poinciana                                poinciana.mid
# 281 | Prelude To A Kiss                        Prelude to a kiss.mid
# 282 | Pure Imagination                         Pure Imagination.mid
# 285 | Rachid                                   Rachid.mid
# 286 | Rain Waltz                               Rainwalt.mid
# 287 | Recardo Bossa Nova                       Recardo.mid
# 288 | Recordame                                Recordame.mid
# 289 | Remember                                 Remember - solo jazz piano.mid
# 290 | Renewal [M]                              Renewaltrio.mid
# 293 | Sammy Walked In                          SammyWalked.mid
# 294 | St Patrick's Day Special                 Danny Boy.mid
# 295 | Secret Love                              McKenzie-secret love.mid
# 296 | Send In The Clowns                       send in the clowns.mid
# 297 | Serenata                                 Serenata solo.mid
# 298 | Shenandoah                               Shenandoah.mid
# 299 | Shiny Stockings                          shinystockings.mid
# 300 | Since We Met                             Since We Met Jazz Kit.mid
# 301 | Sixteen Going On Seventeen               sixteengoing.mid
# 302 | Skylark                                  Skylark 2.mid
# 303 | Strollin'                                Strollin'.mid
# 304 | So In Love (solo)                        SoinLovesolo.mid
# 305 | So In Love (trio)                        SoInlove - trio version.mid
# 306 | Some Day My Prince...                    Some day My Prince.mid
# 308 | Some Other Time                          Some Other Time.mid
# 309 | Something Wonderful                      something wonderful.mid
# 310 | Sometime Ago                             Sometimeago.mid
# 311 | Sonnymoon For 2                          sonnymoo.mid
# 313 | Soon                                     soon.mid
# 314 | Sophisticated Lady                       SophisticatedLady.mid
# 315 | Soul Eyes                                SoulEyessolo.mid
# 316 | Spain / 2                                Spain_2_(Chick_Corea).mid
# 317 | Spain / 3                                spain-3.mid
# 318 | Theme From Spartacus                     Spartacus- 2 pianos.mid
# 319 | Speak Low                                Speak Low (Doug McKenzie).mid
# 320 | Spring Is Here                           Spring Is Here - Bill Evans chords.mid
# 321 | Spring Is Here /2                        Spring is Here 2 (K Barron).mid
# 323 | Spring Is Here /3                        Spring Is Here2-Bill Evans chords.mid
# 327 | Star Eyes                                star eyes.mid
# 328 | Stars Fell On Alabama (duet)             Alabama.mid
# 329 | Stella By Starlight (solo)               Stella solo.mid
# 331 | Stormy Weather                           stormyweather.mid
# 332 | Strange Meadow Lark                      StrangeMeadowlark.mid
# 333 | Surrey/Beautiful Medley                  Surrey medley.mid
# 334 | Sweet And Lovely                         SweetAndLovely.mid
# 335 | Sweet And Lovely (2)                     Sweet1.mid
# 336 | Sweet Lorraine                           Sweetlorraine.mid
# 339 | Take The A Train                         taketheatrain.mid
# 340 | Taking A Chance (on Love)                TakinACh.mid
# 341 | Taking A Chance On Love (solo)           Taking a Chance On Love - Solo piano.mid
# 342 | Tea For Two [M]                          Tea for two.mid
# 343 | That Old Devil Called Love               That Ole Devil Called Love.mid
# 344 | The Duke                                 TheDuke.mid
# 345 | The End Of A Love Affair                 The End of a Love Affair.mid
# 347 | The Folks Who Live...                    The folks who live on the hill.mid
# 348 | The Man That Got Away                    TheManThatGotAway.mid
# 349 | The Masquerade Is Over                   The Masquerade is Over.mid
# 350 | The More I See You                       moreicu.mid
# 352 | The Peacocks                             McKenzie-ThePeacocks.mid
# 353 | The Peanut Vendor                        Peanut Vendor (El Manisero).mid
# 354 | The Song Is You (trio) [M]               TheSongisYoutrio.mid
# 355 | The Summer Wind                          Summer wind 2.mid
# 356 | The Way You Look Tonight (trio)          The Way You look trio.mid
# 358 | There Is No Greater Love                 thereisnogreaterlove.mid
# 359 | These Foolish Things                     These Foolish Things.mid
# 360 | Things Ain't What They Used To Be        Thingsaintwhattheyusedtobe.mid
# 361 | This Nearly Was Mine                     This nearly was mine.mid
# 362 | This Time The Dreams On Me               This Time the Dreams on Me.mid
# 363 | There Will Never Be Another You          There will never be another you.mid
# 364 | They Say Its Wonderful                   They say its wonderful.mid
# 365 | Time After Time                          Time after Time 2.mid
# 367 | Time Remembered /1                       timerem2.mid
# 368 | Time Remembered /2                       Time remembered.mid
# 369 | Too Young To Go Steady                   TooYoungtogoSteady.mid
# 370 | Try A Little Tenderness                  Tryalittle21.mid
# 371 | Try To Remember                          Try To Remember.mid
# 372 | Two For The Road                         Two For The Road 5.mid
# 374 | Turn Out The Stars                       turnoutthestars.mid
# 377 | Up With The Lark                         upwiththelark.mid
# 380 | Very Early (solo)                        Very Early solo piano.mid
# 383 | Waltz For Dave                           Waltse For Dave.mid
# 384 | Warm Valley                              Warmvalleysolo.mid
# 385 | We Will Meet Again                       We Will Meet Again.mid
# 386 | What Is There To Say                     What is there to say.mid
# 388 | What Is This Thing...                    What is this thing - solo.mid
# 389 | When I Fall In Love                      When I Fall in Love.mid
# 390 | Where Is Love                            Where is Love - solo.mid
# 391 | While We're Young                        Whilewereyoung.mid
# 392 | Witchcraft                               Witchcraft.mid
# 394 | Who Can I Turn To?                       WhoCanI.mid
# 395 | Why Did I Choose You                     whydidi.mid
# 396 | Why Do I Love You                        WhyDoILoveYou.mid
# 399 | Yesterday                                Yesterday.mid
# 400 | Yesterdays                               Yesterdays1.mid
# 401 | You Are So Beautiful                     You Are So Beautiful The Grand.mid
# 402 | You Do Something To Me                   You do something to Me.mid
# 404 | You Don't Know What ...                  youdontknow trio.mid
# 405 | You Stepped Out Of...                    You Stepped Out of a Dream (Doug McKenzie).mid
# 406 | You Took Advantage...                    youtookadvantageofme.mid
# 407 | You've Changed                           youhavechanged.mid
# 408 | Young And Foolish                        Young and Foolish.mid
# 412 | Zingaro                                  Zingaro - Jobim.mid
# Total: 297
#   0 http://www.bushgrafts.com/jazz//Midi%20site/afine-1.mid
#   1 http://www.bushgrafts.com/jazz//Midi%20site/afine-2.mid
#   2 http://www.bushgrafts.com/jazz//Midi%20site/Aghostofachance.mid
#   3 http://www.bushgrafts.com/jazz//Midi%20site/AHouseis.mid
#   4 http://www.bushgrafts.com/jazz//Midi%20site/Anighting.mid
#   5 http://www.bushgrafts.com/jazz//Midi%20site/ARemarkYouMade.mid
#   6 http://www.bushgrafts.com/jazz//Midi%20site/A Sleepin' Bee.mid
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-152-a55e7f4518c9> in <module>()
#       1 dmc = DMjazzCrawler()
# ----> 2 dmc .run()
#
# <ipython-input-151-57188ea6667d> in run(self)
#      72                 json.dump(song_dict, f)
#      73
# ---> 74         self.crawl_song(song_dict)
#
# <ipython-input-151-57188ea6667d> in crawl_song(self, song_dict)
#      58             url = self.BASE_URL + '/Midi%20site/' + k
#      59             print('%3d %s' %(idx, url))
# ---> 60             content = self._request_url(url, doctype='content')
#      61
#      62             with open(os.path.join(self.ROOT,k), "wb") as f:
#
# <ipython-input-151-57188ea6667d> in _request_url(self, url, doctype)
#      12
#      13         # sleep
# ---> 14         time.sleep(self.sleep_time)
#      15
#      16         # return
#
# KeyboardInterrupt:
